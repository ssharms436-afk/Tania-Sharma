# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#    Employee_ID   Employee_Name  Age  Gender  Department              Job_Role  \
# 0       EMP001    Aarav Sharma   24    Male          IT    Software Developer
# 1       EMP002     Priya Verma   28  Female          HR          HR Executive
# 2       EMP003     Rohan Gupta   35    Male     Finance            Accountant
# 3       EMP004    Ananya Singh   30  Female   Marketing     Marketing Manager
# 4       EMP005    Vikram Patel   42    Male  Operations    Operations Manager
# 5       EMP006       Neha Jain   26  Female          IT          Data Analyst
# 6       EMP007  Karan Malhotra   29    Male          IT    Software Developer
# 7       EMP008     Simran Kaur   31  Female     Finance     Financial Analyst
# 8       EMP009    Aditya Mehta   27    Male   Marketing   Marketing Executive
# 9       EMP010       Sneha Roy   38  Female          HR            HR Manager
# 10      EMP011       Raj Kumar   25    Male          IT  System Administrator
# ...

# %%
plt.plot(df["Age"],df["Gender"])

# %%
df["Salary"].value_counts().plot(kind ='pie')
plt.show()

# %%
df["Salary"].value_counts().plot(kind ='line')
plt.show()

# %%
df["Salary"].value_counts().plot(kind ='bar')
plt.show()

# %%
df["Salary"].value_counts().plot(kind ='density')
plt.show()

# %%
df["Department"].value_counts().plot(kind ='box')
plt.show()

# %%
df["Salary"].value_counts().plot(kind ='hist')
plt.show()
